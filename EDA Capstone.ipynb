# %%
import pandas as pd
cleaned_income_data=pd.read_excel('income_data.xlsx',index_col=0)
cleaned_income_data.head()
# Out:
#    age                 class_of_worker  industry_code  occupation_code  \
# 0   73                 Not in universe              0                0
# 1   58  Self-employed-not incorporated              4               34
# 2   18                 Not in universe              0                0
# 3    9                 Not in universe              0                0
# 4   10                 Not in universe              0                0
#
#                     education  wage_per_hour enrolled_in_edu_inst_lastwk  \
# 0        High school graduate              0             Not in universe
# 1  Some college but no degree              0             Not in universe
# 2                  10th grade              0                 High school
# 3                    Children              0             Not in universe
# 4                    Children              0             Not in universe
#
#   marital_status          major_industry_code  \
# 0        Widowed  Not in universe or children
# ...

# %%
import seaborn as sns
sns.heatmap(cleaned_income_data.isnull(),cmap='YlGnBu')

# %%
cleaned_income_data.columns
# Out:
# Index(['age', 'class_of_worker', 'industry_code', 'occupation_code',
#        'education', 'wage_per_hour', 'enrolled_in_edu_inst_lastwk',
#        'marital_status', 'major_industry_code', 'major_occupation_code',
#        'race', 'hispanic_origin', 'sex', 'member_of_labor_union',
#        'reason_for_unemployment', 'full_parttime_employment_stat',
#        'capital_gains', 'capital_losses', 'dividend_from_Stocks',
#        'tax_filer_status', 'region_of_previous_residence',
#        'state_of_previous_residence', 'd_household_family_stat',
#        'd_household_summary', 'migration_msa', 'migration_reg',
#        'migration_within_reg', 'live_1_year_ago', 'migration_sunbelt',
#        'num_person_Worked_employer', 'family_members_under_18',
#        'country_father', 'country_mother', 'country_self', 'citizenship',
#        'business_or_self_employed', 'fill_questionnaire_veteran_admin',
#        'veterans_benefits', 'weeks_worked_in_year', 'year', 'income_level'],
# ...

# %%
import matplotlib.pyplot as plt
cleaned_income_data.hist(column='age',by='income_level',xlabelsize=10,ylabelsize=10)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000027E0C4C4D08>,
# ...
#       dtype=object)

# %%
cleaned_income_data.hist(column='class_of_worker',by='income_level',xlabelsize=10,ylabelsize=10,grid=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000027E0C617B88>,
# ...
#       dtype=object)

# %%
cleaned_income_data.hist(column='industry_code',by='income_level',xlabelsize=10,ylabelsize=10,grid=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000027E0D338D08>,
# ...
#       dtype=object)

# %%
ax=sns.countplot(x='industry_code',hue='income_level',data=cleaned_income_data)
# ax = sns.countplot(x="Column", data=ds)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
ids=cleaned_income_data['industry_code']
ids1= cleaned_income_data['income_level']== 50000
ids2= cleaned_income_data['income_level']== -50000
tgf_high_income =cleaned_income_data[ids & ids1]
# tgf_high_income.hist(column='industry_code',by='income_level')
tgf_low_income =cleaned_income_data[ids & ids2]

# %%
sns.countplot(x='industry_code',hue='income_level',data=tgf_high_income)

# %%
sns.countplot(x='industry_code',hue='income_level',data=tgf_low_income)

# %%
# cleaned_income_data.hist(column='occupation_code',by='income_level')
occu_code=cleaned_income_data['occupation_code']
occ_code_high= cleaned_income_data['income_level']==50000
occ_code_low= cleaned_income_data['income_level']==-50000
occ_high=cleaned_income_data[occu_code & occ_code_high]
occ_low=cleaned_income_data[occu_code & occ_code_low]

sns.countplot(x='occupation_code',hue='income_level',data=occ_high)

# %%
sns.countplot(x='occupation_code',hue='income_level',data=occ_low)

# %%
oc_code_high=cleaned_income_data['occupation_code']
occ_code = cleaned_income_data['income_level']==50000
occ_code_high=cleaned_income_data[oc_code_high & occ_code]
occ_code_low = cleaned_income_data['income_level']==-50000
occ_code_low=cleaned_income_data[oc_code_high & occ_code_low]

# %%
# sns.countplot(x='occupation_code',hue='income_level',data=occ_code_high)
# fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=True)
# sns.countplot(x=occ_code_high['occupation_code'],hue=occ_code_high['income_level'], ax=ax1)
# sns.countlot(x=occ_code_low['occupation_code'],hue=occ_code_low['income_level'], ax=ax2)
# # sns.countlot(x='occupation_code',hue=['income_level'], ax=ax2,data=occ_code_low)
plt.figure(figsize=(38,10))
fig, ax =plt.subplots(1,2)
ax1=sns.countplot(x='occupation_code',hue='income_level',data=occ_code_high,ax=ax[0])
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=80, ha="center")
ax2=sns.countplot(x='occupation_code',hue='income_level',data=occ_code_low,ax=ax[1])
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=80, ha="center")
plt.tight_layout()
fig.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   del sys.path[0]

# %%
sns.countplot(x='occupation_code',hue='income_level',data=occ_code_low)

# %%
sns.set(rc={'figure.figsize':(11,8)})

x1=sns.countplot(x='education',hue='income_level',data=cleaned_income_data)
x1.set_xticklabels(x1.get_xticklabels(), rotation=70, ha="right")
# Out:
# [Text(0, 0, 'High school graduate'),
#  Text(0, 0, 'Some college but no degree'),
#  Text(0, 0, '10th grade'),
#  Text(0, 0, 'Children'),
#  Text(0, 0, 'Bachelors degree(BA AB BS)'),
#  Text(0, 0, 'Masters degree(MA MS MEng MEd MSW MBA)'),
#  Text(0, 0, 'Less than 1st grade'),
#  Text(0, 0, 'Associates degree-academic program'),
#  Text(0, 0, '7th and 8th grade'),
#  Text(0, 0, '12th grade no diploma'),
#  Text(0, 0, 'Associates degree-occup /vocational'),
#  Text(0, 0, 'Prof school degree (MD DDS DVM LLB JD)'),
#  Text(0, 0, '5th or 6th grade'),
#  Text(0, 0, '11th grade'),
#  Text(0, 0, 'Doctorate degree(PhD EdD)'),
#  Text(0, 0, '9th grade'),
#  Text(0, 0, '1st 2nd 3rd or 4th grade')]

# %%
# sns.countplot(x='wage_per_hour',hue='income_level',data=cleaned_income_data)
cleaned_income_data.hist(column='wage_per_hour',by='income_level',xlabelsize=8,ylabelsize=8)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000151E6F6FA88>,
# ...
#       dtype=object)

# %%
sns.countplot(x='enrolled_in_edu_inst_lastwk',hue='income_level',data=cleaned_income_data)

# %%
x1=sns.countplot(x='marital_status',hue='income_level',data=cleaned_income_data)
x1.set_xticklabels(x1.get_xticklabels(),rotation=90,ha='right')
# Out:
# [Text(0, 0, 'Widowed'),
#  Text(0, 0, 'Divorced'),
#  Text(0, 0, 'Never married'),
#  Text(0, 0, 'Married-civilian spouse present'),
#  Text(0, 0, 'Separated'),
#  Text(0, 0, 'Married-spouse absent'),
#  Text(0, 0, 'Married-A F spouse present')]

# %%
import matplotlib.pyplot as plt
sns.set(rc={'figure.figsize':(11.7,5)})
x2=sns.countplot(x='major_industry_code',hue='income_level',data=cleaned_income_data)
x2.set_xticklabels(x2.get_xticklabels(),rotation=60,ha='right')
plt.show()

# %%
# sns.set(rc={'figure.figsize':(11,6)}
x1=sns.countplot(x='race',hue='income_level',data=cleaned_income_data)
x1.set_xticklabels(x1.get_xticklabels(),rotation=60,ha='right')
plt.show()
# x2=sns.countplot(x='major_industry_code',hue='income_level',data=cleaned_income_data)

# %%
cleaned_income_data['hispanic_origin'].unique()
sns.set(rc={'figure.figsize':(11,7)})
fig=sns.countplot(x='hispanic_origin',hue='income_level',data=cleaned_income_data)
fig.set_xticklabels(fig.get_xticklabels(),rotation='60',ha='right')
plt.show()

# %%
sns.countplot(x='sex',hue='income_level',data=cleaned_income_data)

# %%
# cleaned_income_data['member_of_labor_union'].unique()
sns.countplot(x='member_of_labor_union',hue='income_level',data=cleaned_income_data)

# %%
# cleaned_income_data['reason_for_unemployment'].unique()
sns.countplot(x='reason_for_unemployment',hue='income_level',data=cleaned_income_data)

# %%
# cleaned_income_data['full_parttime_employment_stat'].unique()
sns.set(rc={'figure.figsize':(11,7)},font='sans-serif',palette='deep')
fig=sns.countplot(x='full_parttime_employment_stat',hue='income_level',data=cleaned_income_data)
fig.set_xticklabels(fig.get_xticklabels(),rotation=60,ha='right')
plt.show()

# %%
# sns.distplot(cleaned_income_data['capital_gains'],hist=True,kde=True,hue='income_level')
cleaned_income_data.hist(column='capital_gains',by='income_level')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000151F569DFC8>,
# ...
#       dtype=object)

# %%
cleaned_income_data[cleaned_income_data['education'] == 'High school graduate']['income_level'].value_counts(dropna = False)
# Out:
# -50000    46528
#  50000     1879
# Name: income_level, dtype: int64

# %%
cleaned_income_data.hist(column='capital_losses',by='income_level')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000151F5CDDC88>,
# ...
#       dtype=object)

# %%
cleaned_income_data.hist(column='dividend_from_Stocks',by='income_level')
# sns.countplot(x='dividend_from_Stocks',hue='income_level',data=cleaned_income_data)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000151E8CE3448>,
# ...
#       dtype=object)

# %%
ax=sns.countplot(x='tax_filer_status',hue='income_level',data=cleaned_income_data)
ax.set_xticklabels(ax.get_xticklabels(),rotation=60,ha='right')
plt.show()

# %%
sns.countplot(x='region_of_previous_residence',hue='income_level',data=cleaned_income_data)

# %%
sns.set(rc={'figure.figsize':(15,6)})
ax=sns.countplot(x='state_of_previous_residence',hue='income_level',data=cleaned_income_data)
ax.set_xticklabels(ax.get_xticklabels(),rotation=60,ha='right')
plt.show()

# %%
cleaned_income_data['d_household_family_stat'].nunique()
sns.set(rc={'figure.figsize':(33,11)})
ax=sns.countplot(x='d_household_family_stat',hue='income_level',data=cleaned_income_data)
ax.set_xticklabels(ax.get_xticklabels(),rotation=60,ha='right',size=20)
plt.show()

# %%
ax=sns.countplot(x='migration_msa',hue='income_level',data=cleaned_income_data)
ax.set_xticklabels(ax.get_xticklabels(),size=20,ha='right')
plt.show()

# %%
ax=sns.countplot(x='migration_reg',hue='income_level',data=cleaned_income_data)
ax.set_xticklabels(ax.get_xticklabels(),rotation=60,size=20,ha='right')
plt.show()

# %%
ax=sns.countplot(x='migration_within_reg',hue='income_level',data=cleaned_income_data)
ax.set_xticklabels(ax.get_xticklabels(),rotation=60,size=20,ha='right')
plt.show()

# %%
ax=sns.countplot(x='live_1_year_ago',hue='income_level',data=cleaned_income_data)
ax.set_xticklabels(ax.get_xticklabels(),rotation=60,size=20,ha='right')
plt.show()

# %%
ax=sns.countplot(x='migration_sunbelt',hue='income_level',data=cleaned_income_data)
ax.set_xticklabels(ax.get_xticklabels(),rotation=60,size=20,ha='right')
plt.show()

# %%
ax=sns.countplot(x='num_person_Worked_employer',hue='income_level',data=cleaned_income_data)
ax.set_xticklabels(ax.get_xticklabels(),rotation=60,size=20,ha='right')
plt.show()

# %%
ax=sns.countplot(x='family_members_under_18',hue='income_level',data=cleaned_income_data)
ax.set_xticklabels(ax.get_xticklabels(),rotation=60,size=20,ha='right')
plt.show()

# %%
ax=sns.countplot(x='country_father',hue='income_level',data=cleaned_income_data)
ax.set_xticklabels(ax.get_xticklabels(),rotation=60,size=20,ha='right')
plt.legend(loc='best')
plt.show()

# %%
ax=sns.countplot(x='country_mother',hue='income_level',data=cleaned_income_data)
ax.set_xticklabels(ax.get_xticklabels(),rotation=60,size=20,ha='right')
plt.legend(loc='best')
plt.show()

# %%
ax=sns.countplot(x='country_self',hue='income_level',data=cleaned_income_data)
ax.set_xticklabels(ax.get_xticklabels(),rotation=60,size=20,ha='right')
plt.legend(loc='best')
plt.show()

# %%
ax=sns.countplot(x='citizenship',hue='income_level',data=cleaned_income_data)
ax.set_xticklabels(ax.get_xticklabels(),rotation=60,size=20,ha='right')
plt.legend(loc='best')
plt.show()

# %%
ax=sns.countplot(x='business_or_self_employed',hue='income_level',data=cleaned_income_data)
ax.set_xticklabels(ax.get_xticklabels(),rotation=60,size=20,ha='right')
plt.legend(loc='best')
plt.show()

# %%
ax=sns.countplot(x='fill_questionnaire_veteran_admin',hue='income_level',data=cleaned_income_data)
ax.set_xticklabels(ax.get_xticklabels(),rotation=60,size=20,ha='right')
plt.legend(loc='best')
plt.show()

# %%
# cleaned_income_data.groupby('fill_questionnaire_veteran_admin').age.agg(['min','max'])
cleaned_income_data.plot(y='fill_questionnaire_veteran_admin',x='age',kind='scatter')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
ax=sns.countplot(x='fill_questionnaire_veteran_admin',hue='income_level',data=cleaned_income_data)
ax.set_xticklabels(ax.get_xticklabels(),rotation=60,size=20,ha='right')
plt.legend(loc='best')
plt.show()

# %%
ax=sns.countplot(x='veterans_benefits',hue='income_level',data=cleaned_income_data)
ax.set_xticklabels(ax.get_xticklabels(),rotation=60,size=20,ha='right')
plt.legend(loc='best')
plt.show()

# %%
ax=sns.countplot(x='weeks_worked_in_year',hue='income_level',data=cleaned_income_data)
ax.set_xticklabels(ax.get_xticklabels(),rotation=60,size=20,ha='right')
plt.legend(loc='best')
plt.show()

# %%
ax=sns.countplot(x='year',hue='income_level',data=cleaned_income_data)
ax.set_xticklabels(ax.get_xticklabels(),rotation=60,size=20,ha='right')
plt.legend(loc='best')
plt.show()

# %%
cleaned_income_data.columns
# Out:
# Index(['age', 'class_of_worker', 'industry_code', 'occupation_code',
#        'education', 'wage_per_hour', 'enrolled_in_edu_inst_lastwk',
#        'marital_status', 'major_industry_code', 'major_occupation_code',
#        'race', 'hispanic_origin', 'sex', 'member_of_labor_union',
#        'reason_for_unemployment', 'full_parttime_employment_stat',
#        'capital_gains', 'capital_losses', 'dividend_from_Stocks',
#        'tax_filer_status', 'region_of_previous_residence',
#        'state_of_previous_residence', 'd_household_family_stat',
#        'd_household_summary', 'migration_msa', 'migration_reg',
#        'migration_within_reg', 'live_1_year_ago', 'migration_sunbelt',
#        'num_person_Worked_employer', 'family_members_under_18',
#        'country_father', 'country_mother', 'country_self', 'citizenship',
#        'business_or_self_employed', 'fill_questionnaire_veteran_admin',
#        'veterans_benefits', 'weeks_worked_in_year', 'year', 'income_level'],
# ...

# %%
cleaned_income_data['education'].value_counts()
# Out:
# High school graduate                      48407
# Children                                  47422
# Some college but no degree                27820
# Bachelors degree(BA AB BS)                19865
# 7th and 8th grade                          8007
# 10th grade                                 7557
# 11th grade                                 6876
# Masters degree(MA MS MEng MEd MSW MBA)     6541
# 9th grade                                  6230
# Associates degree-occup /vocational        5358
# Associates degree-academic program         4363
# 5th or 6th grade                           3277
# 12th grade no diploma                      2126
# 1st 2nd 3rd or 4th grade                   1799
# Prof school degree (MD DDS DVM LLB JD)     1793
# Doctorate degree(PhD EdD)                  1263
# Less than 1st grade                         819
# Name: education, dtype: int64
